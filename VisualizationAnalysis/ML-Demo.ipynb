# %% [markdown]
# # ML- DEMO

# %%
import numpy
from scipy import stats #https://docs.scipy.org/doc/scipy/reference/stats.html  
#statsmodel
#math

#import myStat as ms

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]   #collections

#ms.myStat.describe(speed) #mean:mode,modeCount,median,std,count,var,corr,percentile(25)

x = numpy.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %%
x = numpy.median(speed)
print(x)
# Out:
# 87.0

# %%
x = stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=array([86]), count=array([3]))

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
x = numpy.percentile(ages, 75) #meaning that 75% of the people are 43 or younger.
y = numpy.percentile(ages, 90) 
print(x)
print(y)
# Out:
# 43.0
# 61.0

# %%
#Standard deviation is a measure of uncertainty. A low standard deviation means that most of the numbers are close to the mean (average) value.
#A high standard deviation means that the values are spread out over a wider range.

x = numpy.std(speed) 
print(x)
# Out:
# 9.258292301032677

# %%
#Square root of var() -> std()
speed = [32,111,138,28,59,77,97]
x = numpy.var(speed)
print(x)
# Out:
# 1432.2448979591834

# %% [markdown]
# # Histogram

# %%
x = numpy.random.uniform(0.0, 5.0, 250) #Create an array containing 250 random floats between 0 and 5:
plt.figure(figsize=(10,6))
plt.hist(x, 5)
plt.show()

'''
The first bar represents how many values in the array are between 0 and 1.
The second bar represents how many values are between 1 and 2.

Which gives us this result:   TEST
52 values are between 0 and 1
48 values are between 1 and 2
49 values are between 2 and 3
51 values are between 3 and 4
50 values are between 4 and 5
'''
# Out:
# '\nThe first bar represents how many values in the array are between 0 and 1.\nThe second bar represents how many values are between 1 and 2.\n\nWhich gives us this result:   TEST\n52 values are between 0 and 1\n48 values are between 1 and 2\n49 values are between 2 and 3\n51 values are between 3 and 4\n50 values are between 4 and 5\n'

# %% [markdown]
# # Normal data distribution, or the Gaussian data distribution -- Empirical Rule!

# %%
x = numpy.random.normal(5.0, 1.0, 100000)
plt.figure(figsize=(10,6))
plt.hist(x, 100)
plt.show()
'''
We specify that the mean value is 5.0, and the standard deviation is 1.0.
Meaning that the values should be concentrated around 5.0, and rarely further away than 1.0 from the mean.
And as you can see from the histogram, most values are between 4.0 and 6.0, with a top at approximately 5.0.
'''
# Out:
# '\nWe specify that the mean value is 5.0, and the standard deviation is 1.0.\nMeaning that the values should be concentrated around 5.0, and rarely further away than 1.0 from the mean.\nAnd as you can see from the histogram, most values are between 4.0 and 6.0, with a top at approximately 5.0.\n'

# %% [markdown]
# # Scatter Plot

# %%
ages = [5,7,8,7,2,17,2,9,4,11,12,9,6]
speeds = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.figure(figsize=(10,6))
plt.grid()
plt.scatter(ages, speeds,color='r')
plt.show()

'''
The x-axis represents ages, and the y-axis represents speeds.
What we can read from the diagram is that the two fastest cars were both 2 years old, and the slowest car was 12 years old.
'''
# Out:
# '\nThe x-axis represents ages, and the y-axis represents speeds.\nWhat we can read from the diagram is that the two fastest cars were both 2 years old, and the slowest car was 12 years old.\n'

# %% [markdown]
# # random data distribution

# %%
x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.figure(figsize=(14,8))
plt.scatter(x, y)
plt.grid()
plt.show()

#We can see that the dots are concentrated around the value 5 on the x-axis, and 10 on the y-axis.
#We can also see that the spread is wider on the y-axis than on the x-axis

# %% [markdown]
# # Regression
# The term regression is used when you try to find the relationship between variables. In Machine Learning, and in statistical modeling, that relationship is used to predict the outcome of future events.
#
# ##Linear Regression --
# Linear regression uses the relationship between the data-points to draw a straight line through all them. This line can be used to predict future values.
#
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.linregress.html

# %%
age = [5,7,8,7,2,17,2,9,4,11,12,9,6]                  #y=m (slope) x + c (intercept)
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
result = stats.linregress(age, speed)
result
# Out:
# LinregressResult(slope=-1.751287711552612, intercept=103.10596026490066, rvalue=-0.7585915243761551, pvalue=0.002646873922456101, stderr=0.45353615760774196, intercept_stderr=3.903492810154512)

# %%
age = [5,7,8,7,2,17,2,9,4,11,12,9,6]                  #y=m (slope) x + c (intercept)
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# TEST: Scatter, KDE

#https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html#scipy.stats.linregress
slope, intercept, r_value, p_value, std_err = stats.linregress(age, speed) #dep: x,indep: y


#model predict!
def myfunc(age):
  return slope * age + intercept #speed

mymodel = list(map(myfunc, age)) #M,R,F

''''
This relationship - the coefficient of correlation - is called r.
The r value ranges from -1 to 0 to 1, where 0 means no relationship, and 1 and -1 means 100% related.
'''
print("MyModel :",mymodel)
print("Slope: %f  \nIntercept: %f" % (slope, intercept))
print("R-squared: %f" % r_value**2) #high: 
print("R_Value: ",r_value)
print("P_Value: ",p_value)
print("Std_err: ",std_err)
# Out:
# MyModel : [94.3495217071376, 90.84694628403237, 89.09565857247976, 90.84694628403237, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.1008094186902, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]
# Slope: -1.751288
# Intercept: 103.105960
# R-squared: 0.575461
# R_Value:  -0.7585915243761551
# P_Value:  0.002646873922456101
# Std_err:  0.45353615760774196

# %%
#The value of R-Squared is always between 0 to 1 (0% to 100%). r_value or correlation coefficient
#A high R-Squared value means that many data points are close to the linear regression function line.
#A low R-Squared value means that the linear regression function line does not fit the data well.

#The P-value is a statistical number to conclude if there is a relationship between..ages/speed.
#We test if the true value of the coefficient is equal to zero (no relationship). The statistical test for this is called Hypothesis testing.
#A common threshold of the P-value is 0.05 or 5%. If the P-value is lower than 0.05, we can reject the null hypothesis and conclude that it exist
#no relationship between the variables.

#Linear regression uses the least square method.
#The concept is to draw a line through all the plotted data points. The line is positioned in a way that it minimizes the distance to all of the data points.
#The distance is called "residuals" or "errors"

print(mymodel)
# Out:
# [94.3495217071376, 90.84694628403237, 89.09565857247976, 90.84694628403237, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.1008094186902, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]

# %%
plt.figure(figsize=(10,7))
plt.scatter(age, speed)
plt.grid()
plt.plot(age, mymodel)
plt.show()

# %% [markdown]
# ### Predict Future Values

# %%
predict_speed = myfunc(15)
print(f"Age=15 > Speeed={predict_speed}")
predict_speed = myfunc(25)
print(f"Age=25 > Speeed={predict_speed}")
predict_speed = myfunc(35)
print(f"Age=35 > Speeed={predict_speed}")
predict_speed = myfunc(5)
print(f"Age=5 > Speeed={predict_speed}")
predict_speed = myfunc(8)
print(f"Age=1 > Speeed={predict_speed}")
# Out:
# Age=15 > Speeed=76.83664459161147
# Age=25 > Speeed=59.32376747608536
# Age=35 > Speeed=41.81089036055924
# Age=5 > Speeed=94.3495217071376
# Age=1 > Speeed=89.09565857247976

# %% [markdown]
# ### Bad Fit: Let us create an example where linear regression would not be the best method to predict future values.

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40,50]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15, 80]

plt.figure(figsize=(10,7))
plt.scatter(x, y)
plt.show()

result = stats.linregress(x, y)   #0.45, 3.90
result
# Out:
# LinregressResult(slope=0.03493645823740678, intercept=41.392512355342724, rvalue=0.03183751068146133, pvalue=0.8910322512031121, stderr=0.25161860670168046, intercept_stderr=12.491588047761969)

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40,50]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15,80]

slope, intercept, r_value, p, std_err = stats.linregress(x, y)

def myfunc1(x):
  return slope * x + intercept

print("Slope: %f  \nIntercept: %f" % (slope, intercept))
print("R-squared: %f" % r_value**2)
print("R_Value: ",r_value)
print("P_Value: ",p_value)

mymodel = list(map(myfunc1, x))
plt.figure(figsize=(10,7))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# Slope: 0.034936
# Intercept: 41.392512
# R-squared: 0.001014
# R_Value:  0.03183751068146133
# P_Value:  0.002646873922456101

# %%
myfunc1(50)
# Out:
# 43.13933526721306

# %% [markdown]
# ## Machine Learning - Train/Test

# %% [markdown]
# '''
# Train/Test is a method to measure the accuracy of your model. It is called Train/Test because you split the the data set into two sets: a training set and a testing set. 80% for training, and 20% for testing.
#
# You train the model using the training set.You test the model using the testing set.
# Train the model means create the model.Test the model means test the accuracy of the model.
# '''

# %%
x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(100, 40, 100) / x
plt.figure(figsize=(10,7))
plt.scatter(x, y)
plt.show()

# %%
print(x[::20])
print(y[::20])
# Out:
# [3.58528102 5.10354607 1.94144342 4.22830782 2.21503065]
# [26.01411206 36.21382569 42.42909091 18.31413196 38.31632458]

# %%
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

# %%
plt.figure(figsize=(10,7))
plt.grid()
plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y,color='r')
plt.show()

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.poly1d.html
#https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html?highlight=polyfit#numpy.polyfit     

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4)) #4: degree (numpy.polyfit: Least squares polynomial fit.)
from sklearn.metrics import r2_score

#Training
r2 = r2_score(train_y, mymodel(train_x)) #r_square: from sklearn!
print(r2)
# Out:
# 0.8894067107535775

# %%
#Testing: red dot
r2 = r2_score(test_y, mymodel(test_x))
print(r2)
# Out:
# -0.19110198552890467

# %%
#Predict
print(mymodel(2))
# Out:
# 53.654209692853726

# %%
#https://numpy.org/doc/stable/reference/generated/numpy.linspace.html  
plt.figure(figsize=(14,9))

plt.grid()
plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y,color='r')

myline = numpy.linspace(1, 6, 100) 
#start. stop. no_of_sample +ve 
#Example: np.linspace(2.0, 3.0, num=5) == array([2.  , 2.25, 2.5 , 2.75, 3.  ])

plt.plot(myline, mymodel(myline))
plt.show()

# %%
#Predict
print(mymodel(5))
# Out:
# 35.65639138644207
