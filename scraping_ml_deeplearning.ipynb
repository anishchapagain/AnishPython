# %% [markdown]
# <a href="https://colab.research.google.com/github/anishchapagain/AnishPython/blob/master/scraping_ml_deeplearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
ai_words = [
    "Algorithm", "Artificial Intelligence", "Machine Learning", "Deep Learning", "Data Science", "Neural Networks", "Big Data", "Computer Vision", "Natural Language Processing",
    "Supervised Learning", "Unsupervised Learning", "Reinforcement Learning", "Data Mining", "Predictive Analytics", "Clustering", "Classification", "Regression", "Decision Trees",
    "Random Forest", "Support Vector Machines", "Naive Bayes", "K-Means", "Gradient Descent", "Backpropagation", "Overfitting", "Underfitting", "Regularization",
    "Hyperparameter Tuning", "Cross-Validation", "Bias", "Variance", "Accuracy", "Precision", "Recall", "F1-Score", "ROC Curve", "AUC", "Confusion Matrix", "Data Preprocessing",
    "Feature Engineering", "Dimensionality Reduction", "Principal Component Analysis", "T-SNE", "Autoencoders", "Transfer Learning", "Generative Adversarial Networks",
    "Convolutional Neural Networks", "Recurrent Neural Networks", "Long Short-Term Memory", "Transformers", "BERT", "GPT-3", "TensorFlow", "PyTorch", "Keras", "Scikit-Learn",
    "Pandas", "NumPy", "Matplotlib", "Seaborn", "Data Visualization", "Data Wrangling", "Data Cleaning", "Exploratory Data Analysis", "Statistical Modeling", "Time Series Analysis",
    "Anomaly Detection", "Recommender Systems", "Chatbots", "Robotics", "Autonomous Vehicles", "Image Recognition", "Object Detection", "Speech Recognition", "Machine Translation",
    "Sentiment Analysis", "Text Summarization", "Question Answering", "Knowledge Graphs", "Explainable AI", "AI Ethics", "Fairness", "Accountability", "Transparency"
    ]

# %%
print(ai_words)
# Out:
# ['Algorithm', 'Artificial Intelligence', 'Machine Learning', 'Deep Learning', 'Data Science', 'Neural Networks', 'Big Data', 'Computer Vision', 'Natural Language Processing', 'Supervised Learning', 'Unsupervised Learning', 'Reinforcement Learning', 'Data Mining', 'Predictive Analytics', 'Clustering', 'Classification', 'Regression', 'Decision Trees', 'Random Forest', 'Support Vector Machines', 'Naive Bayes', 'K-Means', 'Gradient Descent', 'Backpropagation', 'Overfitting', 'Underfitting', 'Regularization', 'Hyperparameter Tuning', 'Cross-Validation', 'Bias', 'Variance', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC Curve', 'AUC', 'Confusion Matrix', 'Data Preprocessing', 'Feature Engineering', 'Dimensionality Reduction', 'Principal Component Analysis', 'T-SNE', 'Autoencoders', 'Transfer Learning', 'Generative Adversarial Networks', 'Convolutional Neural Networks', 'Recurrent Neural Networks', 'Long Short-Term Memory', 'Transformers', 'BERT', 'GPT-3', 'TensorFlow', 'PyTorch', 'Ker
# ...

# %%
genai_words = ["Large Language Model", "Generative Model", "Transformer", "Attention Mechanism", "Tokenization", "Embedding", "Encoder", "Decoder", "Autoregressive Model", "Sequence-to-Sequence", "Neural Machine Translation", "Text Generation", "Language Modeling", "Natural Language Understanding", "Natural Language Generation", "Contextual Embeddings", "Word Embeddings", "Subword Embeddings", "Byte Pair Encoding", "WordPiece", "SentencePiece", "Pre-training", "Fine-tuning", "Transfer Learning", "Zero-Shot Learning", "Few-Shot Learning", "Multi-task Learning", "Domain Adaptation", "Data Augmentation", "Adversarial Training", "Beam Search", "Greedy Decoding", "Nucleus Sampling", "Top-K Sampling", "Top-P Sampling", "Perplexity", "BLEU Score", "ROUGE Score", "METEOR Score", "CIDEr Score", "Human Evaluation", "Interpretability", "Explainability", "Bias Mitigation", "Fairness", "Robustness", "Security", "Privacy", "Ethics", "GPT-3", "GPT-4", "LaMDA", "PaLM", "Jurassic-1 Jumbo", "Megatron-Turing NLG", "WuDao 2.0", "BLOOM", "Chinchilla", "Sparrow", "Claude", "Bard", "OpenAI", "Google AI", "DeepMind", "Meta AI", "Hugging Face", "AI21 Labs", "Cohere", "Anthropic", "Stability AI", "EleutherAI", "BigScience", "Common Crawl", "Wikipedia", "BooksCorpus", "GitHub", "Reddit", "Twitter", "WebText", "C4", "The Pile", "RealToxicityPrompts", "Winogrande", "SuperGLUE", "SQuAD", "GLUE", "MNLI", "QNLI", "RTE", "SST-2", "CoLA", "MRPC", "QQP", "STS-B", "BoolQ", "COPA", "MultiRC", "WiC", "WSC", "RACE", "DROP", "SWAG", "HellaSwag", "ARC", "OpenBookQA", "Natural Questions", "TriviaQA", "HotpotQA", "CommonsenseQA", "Visual Question Answering", "Image Captioning", "Video Captioning", "Dialogue Systems", "Chatbots", "Virtual Assistants", "Question Answering Systems", "Summarization Systems", "Machine Translation Systems", "Text Generation Systems", "Code Generation", "Code Completion", "Code Translation", "Software Development", "Data Science", "Machine Learning", "Artificial Intelligence", "Deep Learning"]

random_genai_words = random.sample(genai_words, 100)

print(random_genai_words)
# Out:
# ['BoolQ', 'Explainability', 'BigScience', 'Byte Pair Encoding', 'Tokenization', 'LaMDA', 'Natural Language Generation', 'Sparrow', 'GPT-4', 'TriviaQA', 'Pre-training', 'SWAG', 'Stability AI', 'Data Science', 'OpenBookQA', 'Machine Learning', 'Domain Adaptation', 'Neural Machine Translation', 'Dialogue Systems', 'Code Completion', 'Subword Embeddings', 'Privacy', 'Language Modeling', 'Fine-tuning', 'Autoregressive Model', 'Perplexity', 'AI21 Labs', 'Greedy Decoding', 'Beam Search', 'The Pile', 'Adversarial Training', 'DROP', 'Twitter', 'DeepMind', 'BLOOM', 'Transformer', 'Top-K Sampling', 'Nucleus Sampling', 'Virtual Assistants', 'GLUE', 'OpenAI', 'Anthropic', 'SentencePiece', 'Bias Mitigation', 'Jurassic-1 Jumbo', 'Question Answering Systems', 'Text Generation', 'Reddit', 'Deep Learning', 'SQuAD', 'Chinchilla', 'Summarization Systems', 'Attention Mechanism', 'Google AI', 'MNLI', 'RealToxicityPrompts', 'Cohere', 'Data Augmentation', 'Common Crawl', 'Meta AI', 'WuDao 2.0', 'Multi-task 
# ...

# %%
web_scraping_words = [
    "Crawling", "Scraping", "Parsing", "Extraction", "Data Mining", "Web Harvesting", "Screen Scraping", "Data Acquisition",
    "Information Retrieval", "Web Data Extraction", "HTML Parsing", "XML Parsing", "JSON Parsing", "Regular Expressions",
    "Beautiful Soup", "Scrapy", "Selenium", "Requests", "lxml", "urllib", "Web Automation", "Browser Automation",
    "Headless Browsing", "Proxy Servers", "IP Rotation", "User Agents", "CAPTCHA Solving", "Anti-Bot Techniques",
    "Rate Limiting", "Throttling", "Data Cleaning", "Data Transformation", "Data Storage", "Database Integration",
    "Web Crawlers", "Web Spiders", "Robots.txt", "Sitemap", "XPath", "CSS Selectors", "DOM Traversal", "Data Validation",
    "Data Normalization", "Data Deduplication", "Data Enrichment", "Data Analysis", "Data Visualization",
    "Web Scraping APIs", "Web Scraping Services", "Ethical Scraping", "Legal Compliance", "Terms of Service",
    "Copyright Infringement", "Privacy Concerns", "Data Security", "Web Scraping Tools", "Web Scraping Libraries",
    "Open Source Scrapers", "Commercial Scrapers", "Cloud-Based Scrapers", "Distributed Scraping", "Scalable Scraping",
    "Web Scraping Best Practices", "Web Scraping Challenges", "Web Scraping Use Cases", "E-commerce Scraping",
    "Social Media Scraping", "News Scraping", "Real Estate Scraping", "Job Scraping", "Travel Scraping",
    "Financial Data Scraping", "Product Data Scraping", "Price Comparison", "Market Research", "Sentiment Analysis",
    "Lead Generation", "Competitive Intelligence", "Business Intelligence", "Data-Driven Decision Making"
]

print(web_scraping_words)
# Out:
# ['Crawling', 'Scraping', 'Parsing', 'Extraction', 'Data Mining', 'Web Harvesting', 'Screen Scraping', 'Data Acquisition', 'Information Retrieval', 'Web Data Extraction', 'HTML Parsing', 'XML Parsing', 'JSON Parsing', 'Regular Expressions', 'Beautiful Soup', 'Scrapy', 'Selenium', 'Requests', 'lxml', 'urllib', 'Web Automation', 'Browser Automation', 'Headless Browsing', 'Proxy Servers', 'IP Rotation', 'User Agents', 'CAPTCHA Solving', 'Anti-Bot Techniques', 'Rate Limiting', 'Throttling', 'Data Cleaning', 'Data Transformation', 'Data Storage', 'Database Integration', 'Web Crawlers', 'Web Spiders', 'Robots.txt', 'Sitemap', 'XPath', 'CSS Selectors', 'DOM Traversal', 'Data Validation', 'Data Normalization', 'Data Deduplication', 'Data Enrichment', 'Data Analysis', 'Data Visualization', 'Web Scraping APIs', 'Web Scraping Services', 'Ethical Scraping', 'Legal Compliance', 'Terms of Service', 'Copyright Infringement', 'Privacy Concerns', 'Data Security', 'Web Scraping Tools', 'Web Scraping Li
# ...

# %%
topics = [
    "Data Science", "Data Analysis", "Deep Learning", "Perceptron", "Backpropagation",
    "Multilayer Perceptron", "Gradient Descent", "Stochastic Gradient", "Optimizer",
    "Photo Receptors", "Associators", "Responders", "Visualization", "Data Cleaning",
    "Data Mining", "Knowledge Management", "Transformers", "Machine Learning",
    "Neural Networks", "Artificial NN", "ANN", "Recurrent Neural Network", "RNN",
    "BERT", "GPT", "Huggingface", "Pipeline", "Jupyter Notebook", "ipynb", "Python",
    "Loss function", "Bias", "Weight", "Retrival Augemented Generative", "LLM", "Sigmoid",
    "Rectified Linear Unit", "ReLU", "CUDA", "NVIDIA", "ChatGPT", "Gemini", "Attention",
    "Embedding", "RAG", "Knowledge Graphs", "k-NN", "Nearest Neighbors", "Regression",
    "Classification", "Embeddings", "Fine-tune", "unembedding", "Temperature",
    "OPENAI_API_KEY", "API_KEY", "Finetuning", "prompt", "Accuracy", "precision",
    "recall", "F1-score", "confusion matrix", "MNIST", "Vector", "LSTM", "pretrain",
    "LSTM", "BRNN", "Decision Tree", "Support Vector Machines", "SVM", "GPT",
    "Generative pretrained transformers", "Incremental Learning", "Batch Learning",
    "Neural Networks", "Activation", "Generative Adversial Network", "GAN",
    "Convolutional NN", "CNN", "PyTorch", "Gradio", "Panel", "Q&A", "LangChain",
    "Google Colab", "Models", "AI - ML - NN - DL - GenAI - LLM NLP",
    "Natural Language Programming", "NLP", "Natural Language Understanding",
    "Natural Language Generation", "NLU", "NLG", "Tensor", "Large Language Models",
    "Generative AI", "GenAI", "Technological",
    "Automation", "1789533392", "1837636211",
    "Web Scraping", "Data Extraction", "OCR",
    "Optical Character Recognition", "Google Cloud", "AWS", "Sentiment Analysis",
    "Summarization", "Naive Bayes"]

print(topics)
# Out:
# ['Data Science', 'Data Analysis', 'Deep Learning', 'Perceptron', 'Backpropagation', 'Multilayer Perceptron', 'Gradient Descent', 'Stochastic Gradient', 'Optimizer', 'Photo Receptors', 'Associators', 'Responders', 'Visualization', 'Data Cleaning', 'Data Mining', 'Knowledge Management', 'Transformers', 'Machine Learning', 'Neural Networks', 'Artificial NN', 'ANN', 'Recurrent Neural Network', 'RNN', 'BERT', 'GPT', 'Huggingface', 'Pipeline', 'Jupyter Notebook', 'ipynb', 'Python', 'Loss function', 'Bias', 'Weight', 'Retrival Augemented Generative', 'LLM', 'Sigmoid', 'Rectified Linear Unit', 'ReLU', 'CUDA', 'NVIDIA', 'ChatGPT', 'Gemini', 'Attention', 'Embedding', 'RAG', 'Knowledge Graphs', 'k-NN', 'Nearest Neighbors', 'Regression', 'Classification', 'Embeddings', 'Fine-tune', 'unembedding', 'Temperature', 'OPENAI_API_KEY', 'API_KEY', 'Finetuning', 'prompt', 'Accuracy', 'precision', 'recall', 'F1-score', 'confusion matrix', 'MNIST', 'Vector', 'LSTM', 'pretrain', 'LSTM', 'BRNN', 'Decision Tr
# ...

# %%
all_words = list(set(ai_words + genai_words + web_scraping_words + topics))
print(all_words)
# Out:
# ['Robustness', 'Web Scraping Use Cases', 'Seaborn', 'Subword Embeddings', 'GAN', 'Sparrow', 'Panel', 'CoLA', 'Embedding', 'Few-Shot Learning', 'Lead Generation', 'C4', 'Fine-tuning', 'DROP', 'Fine-tune', 'Generative AI', 'Explainable AI', 'COPA', 'HellaSwag', 'Vector', 'prompt', 'Predictive Analytics', 'AUC', 'Machine Translation', 'QQP', 'ANN', 'precision', 'WordPiece', 'Keras', 'Web Scraping Libraries', 'Weight', 'Regularization', 'Natural Language Understanding', 'TriviaQA', 'LangChain', 'urllib', 'Database Integration', 'GPT', 'BLEU Score', 'Knowledge Graphs', 'HTML Parsing', 'Data Preprocessing', 'Chatbots', 'Zero-Shot Learning', 'PaLM', 'Data Mining', 'Data Wrangling', 'RTE', 'Real Estate Scraping', 'Computer Vision', 'DOM Traversal', 'Variance', 'Huggingface', 'Data Science', 'Backpropagation', 'Transformers', 'T-SNE', 'News Scraping', 'Requests', 'unembedding', 'Ethics', 'Decision Tree', 'Transformer', 'Data Analysis', 'CUDA', 'Web Data Extraction', 'Headless Browsing', 'SVM'
# ...

# %%
weighted_words = {}
for word in all_words:
  weight = 1  # Default weight
  if word in ["Data Science", "Deep Learning", "Machine Learning", "Artificial Intelligence"]:
    weight = 3  # Higher weight for important words
  elif word in ["Python", "TensorFlow", "PyTorch"]:
    weight = 2  # Medium weight for relevant tools
  weighted_words[word] = weight
print(weighted_words)
# Out:
# {'Robustness': 1, 'Web Scraping Use Cases': 1, 'Seaborn': 1, 'Subword Embeddings': 1, 'GAN': 1, 'Sparrow': 1, 'Panel': 1, 'CoLA': 1, 'Embedding': 1, 'Few-Shot Learning': 1, 'Lead Generation': 1, 'C4': 1, 'Fine-tuning': 1, 'DROP': 1, 'Fine-tune': 1, 'Generative AI': 1, 'Explainable AI': 1, 'COPA': 1, 'HellaSwag': 1, 'Vector': 1, 'prompt': 1, 'Predictive Analytics': 1, 'AUC': 1, 'Machine Translation': 1, 'QQP': 1, 'ANN': 1, 'precision': 1, 'WordPiece': 1, 'Keras': 1, 'Web Scraping Libraries': 1, 'Weight': 1, 'Regularization': 1, 'Natural Language Understanding': 1, 'TriviaQA': 1, 'LangChain': 1, 'urllib': 1, 'Database Integration': 1, 'GPT': 1, 'BLEU Score': 1, 'Knowledge Graphs': 1, 'HTML Parsing': 1, 'Data Preprocessing': 1, 'Chatbots': 1, 'Zero-Shot Learning': 1, 'PaLM': 1, 'Data Mining': 1, 'Data Wrangling': 1, 'RTE': 1, 'Real Estate Scraping': 1, 'Computer Vision': 1, 'DOM Traversal': 1, 'Variance': 1, 'Huggingface': 1, 'Data Science': 3, 'Backpropagation': 1, 'Transformers': 1, '
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Create a WordCloud object with the emphasized words
wordcloud = WordCloud(width=800, height=400, background_color='white', min_font_size=10).generate_from_frequencies(weighted_words)

# Plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %%
weighted_words = {}
for word in all_words:
  if word in ["Data Science", "Deep Learning", "Machine Learning", "Artificial Intelligence", "Attention", "NN"]:
    weight = 10  # Higher weight for important words
  elif word in ["Python", "TensorFlow", "PyTorch"]:
    weight = 9  # Medium weight for relevant tools
  weighted_words[word] = weight
  weight = 1  # Default weight

print(weighted_words)

wordcloud = WordCloud(width=1000, height=600, background_color='white').generate_from_frequencies(weighted_words)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# Save the image
wordcloud.to_file('wordcloud_dl.jpg')
# Out:
# {'Robustness': 1, 'Web Scraping Use Cases': 1, 'Seaborn': 1, 'Subword Embeddings': 1, 'GAN': 1, 'Sparrow': 1, 'Panel': 1, 'CoLA': 1, 'Embedding': 1, 'Few-Shot Learning': 1, 'Lead Generation': 1, 'C4': 1, 'Fine-tuning': 1, 'DROP': 1, 'Fine-tune': 1, 'Generative AI': 1, 'Explainable AI': 1, 'COPA': 1, 'HellaSwag': 1, 'Vector': 1, 'prompt': 1, 'Predictive Analytics': 1, 'AUC': 1, 'Machine Translation': 1, 'QQP': 1, 'ANN': 1, 'precision': 1, 'WordPiece': 1, 'Keras': 1, 'Web Scraping Libraries': 1, 'Weight': 1, 'Regularization': 1, 'Natural Language Understanding': 1, 'TriviaQA': 1, 'LangChain': 1, 'urllib': 1, 'Database Integration': 1, 'GPT': 1, 'BLEU Score': 1, 'Knowledge Graphs': 1, 'HTML Parsing': 1, 'Data Preprocessing': 1, 'Chatbots': 1, 'Zero-Shot Learning': 1, 'PaLM': 1, 'Data Mining': 1, 'Data Wrangling': 1, 'RTE': 1, 'Real Estate Scraping': 1, 'Computer Vision': 1, 'DOM Traversal': 1, 'Variance': 1, 'Huggingface': 1, 'Data Science': 10, 'Backpropagation': 1, 'Transformers': 1, 
# ...
