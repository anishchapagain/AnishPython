# %%
import folium  #Basemap, plotyly, ggplot2
from folium.plugins import MiniMap
from folium.plugins import MousePosition

# %%
m = folium.Map(location=(27.70169, 85.3206), zoom_start=13)
MousePosition(position="topright", separator=" , ",lng_first=False,prefix="Coordinates:").add_to(m)
minimap = MiniMap()
m.add_child(minimap)
#m = folium.Map(location=[27.70169, 85.3206])
#m.save("index.html") #icon=folium.Icon(color="red", icon="info-sign"),
#color: {'beige', 'black', 'orange', 'red', 'lightred', 'pink', 'darkblue', 'gray', 'white', 'darkpurple', 'darkred', 'lightgreen', 'purple', 'cadetblue', 'blue', 'lightblue', 'lightgray', 'darkgreen', 'green'}

#folium.Marker([27.7375,85.3858], popup="<b>Gokarneshwar</b>", tooltip='Gokarneshwar',icon=folium.Icon(color="green", icon="cloud")).add_to(m)
folium.Marker([27.71793,85.40152], popup="<b>Mulpani</b>", tooltip='Mulpani',icon=folium.Icon(color="red", icon="home")).add_to(m)
folium.Marker([27.68565,85.34626], popup="<b>Gurans Life Insurance</b>", tooltip='Gurans Life',icon=folium.Icon(color="purple", icon="star")).add_to(m)
folium.Marker([27.733,85.328], popup="<b>Sheetal Niwas</b>", tooltip='President-House',icon=folium.Icon(color="green", icon="star")).add_to(m)
'''
folium.CircleMarker(
    location=[27.7375,85.3858],
    radius=20,
    popup="Gokarneshwar",
    color="#3186cc",
    fill=True,
    fill_color="#3186cc",
).add_to(m)
'''
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
