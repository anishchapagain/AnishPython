# %%
#vlookup: merge two table into one using some column

import pandas as pd

# %%
people = {
    "first": ["Charlie", 'Jane', 'Uncle'], 
    "last": ["Chaplin", 'Does', 'Ben'], 
    "email": ["chaplin@gmail.com", 'JaneDoes@email.com', 'ben@email.com']
}
df1=pd.DataFrame(people)
df1
# Out:
#      first     last               email
# 0  Charlie  Chaplin   chaplin@gmail.com
# 1     Jane     Does  JaneDoes@email.com
# 2    Uncle      Ben       ben@email.com

# %%
people2 = {
    "first": ["Charlie", 'Jane', 'Uncle'], 
    "age": [30, 40, 50], 
    "country": ["USA", 'Trinidad', 'UK']
}
df2=pd.DataFrame(people2)
df2
# Out:
#      first  age   country
# 0  Charlie   30       USA
# 1     Jane   40  Trinidad
# 2    Uncle   50        UK

# %%
df1.append(df2)  #pd.concat([df1,df2])
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
#merge: by key!

#final = df1.merge(df2)  #SQL: JOIN
final = df1.merge(df2)#,how='inner')#, left, right, outer'!

# %%
final
# Out:
#      first     last               email  age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   30       USA
# 1     Jane     Does  JaneDoes@email.com   40  Trinidad
# 2    Uncle      Ben       ben@email.com   50        UK

# %%
a="Python"
b="Programming"
a+b
# Out:
# 'PythonProgramming'

# %%
#concat: similar to merge but more playble!

finalNew = pd.concat([df1,df2]) # df1.append(df2)  -->  #set theory!

# %%
finalNew   # issue here: two columns named 'first' exists!
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
#finalNew.notna().count()
#x=finalNew
x=finalNew.copy()
x
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
x.fillna('',inplace=True)
x
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com
# 1     Jane     Does  JaneDoes@email.com
# 2    Uncle      Ben       ben@email.com
# 0  Charlie                               30.0       USA
# 1     Jane                               40.0  Trinidad
# 2    Uncle                               50.0        UK

# %%
finalNew
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
#pop column 'first', will remove both 'first'

#finalNew.pop('first')
#best solution would be: df.T.drop_duplicates().T

# %%
xyz=finalNew.copy()
xyz
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
xyz.T
# Out:
#                          0                   1              2        0  \
# first              Charlie                Jane          Uncle  Charlie
# last               Chaplin                Does            Ben      NaN
# email    chaplin@gmail.com  JaneDoes@email.com  ben@email.com      NaN
# age                    NaN                 NaN            NaN     30.0
# country                NaN                 NaN            NaN      USA
#
#                 1      2
# first        Jane  Uncle
# last          NaN    NaN
# email         NaN    NaN
# age          40.0   50.0
# country  Trinidad     UK

# %%
xyz.T.drop_duplicates()
# Out:
#                          0                   1              2        0  \
# first              Charlie                Jane          Uncle  Charlie
# last               Chaplin                Does            Ben      NaN
# email    chaplin@gmail.com  JaneDoes@email.com  ben@email.com      NaN
# age                    NaN                 NaN            NaN     30.0
# country                NaN                 NaN            NaN      USA
#
#                 1      2
# first        Jane  Uncle
# last          NaN    NaN
# email         NaN    NaN
# age          40.0   50.0
# country  Trinidad     UK

# %%
xyz.T.drop_duplicates().T
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
xyz
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
df1
# Out:
#      first     last               email
# 0  Charlie  Chaplin   chaplin@gmail.com
# 1     Jane     Does  JaneDoes@email.com
# 2    Uncle      Ben       ben@email.com

# %%
df2
# Out:
#      first  age   country
# 0  Charlie   30       USA
# 1     Jane   40  Trinidad
# 2    Uncle   50        UK

# %%
#concat without Duplicate Column

final2=pd.concat([df1,df2])

# %%
final2
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 0  Charlie      NaN                 NaN  30.0       USA
# 1     Jane      NaN                 NaN  40.0  Trinidad
# 2    Uncle      NaN                 NaN  50.0        UK

# %%
#concat: inner (takes only matching columns)
# SQL
final3=pd.concat([df1,df2],join='inner')  #intersection

# %%
final3
# Out:
#      first
# 0  Charlie
# 1     Jane
# 2    Uncle
# 0  Charlie
# 1     Jane
# 2    Uncle

# %%
final4=pd.concat([df1,df2],join='outer',ignore_index=True) #sort=False, inplace=True    # Union

# %%
final4
# Out:
#      first     last               email   age   country
# 0  Charlie  Chaplin   chaplin@gmail.com   NaN       NaN
# 1     Jane     Does  JaneDoes@email.com   NaN       NaN
# 2    Uncle      Ben       ben@email.com   NaN       NaN
# 3  Charlie      NaN                 NaN  30.0       USA
# 4     Jane      NaN                 NaN  40.0  Trinidad
# 5    Uncle      NaN                 NaN  50.0        UK

# %% [markdown]
# ## Crosstab

# %%
pd.crosstab(final4.country,final4.age)    #count()   #advanced -> pivot_table: mean()
# Out:
# age       30.0  40.0  50.0
# country
# Trinidad     0     1     0
# UK           0     0     1
# USA          1     0     0
