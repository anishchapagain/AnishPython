# %% [markdown]
# # EarthQuake Data:
# Columns: Date,Time,Latitude,Longitude,Magnitude,Epicentre

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %% [markdown]
# # Read CSV file

# %%
raw = pd.read_csv('test.csv',parse_dates=['Date'])
#raw[raw.Date.str.contains(r'/')]

# %%
raw #100,00
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude       Date
# 0       85.39    27.58        Lalitpur  14:45        4.1 2015-06-26
# 1       85.49    27.94  Sindhupalchowk  23:51        4.2 2015-06-25
# 2       86.21    27.66         Dolakha  23:49        4.1 2015-06-25
# 3       85.17    27.78         Nuwakot  21:07        4.3 2015-06-25
# 4       85.75    27.85  Sindhupalchowk  14:59        4.0 2015-06-24
# ..        ...      ...             ...    ...        ...        ...
# 437     84.71    28.14          Gorkha  01:52        4.2 2015-04-26
# 438     85.35    28.05          Rasuwa  01:49        4.0 2015-04-26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1 2015-04-26
# 440     85.43    27.71       Kathmandu  00:43        4.6 2015-04-26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1 2015-04-26
#
# [442 rows x 6 columns]

# %%
raw[raw.Longitude.str.contains(':')]  #279
# Out:
# Empty DataFrame
# Columns: [Longitude, Latitude, Epicentre, Time, Magnitude, Date]
# Index: []

# %%
raw[raw.Latitude.str.contains(':')]  #279
# Out:
# Empty DataFrame
# Columns: [Longitude, Latitude, Epicentre, Time, Magnitude, Date]
# Index: []

# %%
raw.iloc[[278,279,281,416,417]]
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude       Date
# 278     85.41    28.01         Nuwakot  15:05        4.2 2015-05-08
# 279     85:64    27:93  Sindhupalchowk  23:34        4.0 2015-06-29
# 281      86.2    27.35       Ramechhap  05:42        5.0 2015-06-29
# 416        86    27.79  Sindhupalchowk  14:25        4.8 2015-04-26
# 417     86.05    27.94           Tibet  13:22        5.0 2015-04-26

# %%
raw.dtypes
# Out:
# Longitude            object
# Latitude             object
# Epicentre            object
# Time                 object
# Magnitude           float64
# Date         datetime64[ns]
# dtype: object

# %%
raw[raw['Longitude']=='85:64']['Longitude']
# Out:
# 279    85:64
# Name: Longitude, dtype: object

# %%
raw.loc[raw['Longitude']=='85:64','Longitude']='85.64'
#raw.loc[raw['Longitude']=='86','Longitude']='86.00'
raw.loc[raw['Latitude']=='27:93','Latitude']='27.93'
raw.iloc[[278,279,416,417]]
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude       Date
# 278     85.41    28.01         Nuwakot  15:05        4.2 2015-05-08
# 279     85.64    27.93  Sindhupalchowk  23:34        4.0 2015-06-29
# 416        86    27.79  Sindhupalchowk  14:25        4.8 2015-04-26
# 417     86.05    27.94           Tibet  13:22        5.0 2015-04-26

# %%
raw[["Longitude", "Latitude"]] = raw[["Longitude", "Latitude"]].apply(pd.to_numeric) #imp!

# %%
raw.dtypes
# Out:
# Longitude           float64
# Latitude            float64
# Epicentre            object
# Time                 object
# Magnitude           float64
# Date         datetime64[ns]
# dtype: object

# %%
raw.to_csv('earthquakeTest.csv')

# %% [raw]
# description = "Disclaimer: this profiling report was generated using a sample of 5% of the original dataset."
# raw.profile_report(title="Nepal EarthQuake 2015",html={'style':{'full_width':True}},sort='ascending',minimal=True,dataset=dict(
#         description="This profiling report was generated using a sample of 5% of the original dataset.",
#         copyright_holder="StataCorp LLC",
#         copyright_year="2020",
#         url="http://www.stata-press.com/data/r15/auto2.dta",
#     ))

# %%
prof = ProfileReport(raw)
prof.to_file(output_file='earthquake_test.html')
# Out:
# Summarize dataset:   0%|          | 0/19 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataDate = pd.read_csv('earthquake.csv',parse_dates=['Date'])
dataDate.dtypes
# Out:
# Longitude            object
# Latitude             object
# Epicentre            object
# Time                 object
# Magnitude           float64
# Date         datetime64[ns]
# dtype: object

# %%
type(dataDate)
# Out:
# pandas.core.frame.DataFrame

# %%
#dir(dataDate)

# %%
dataDate.head(70)[60:70]
# Out:
#    Longitude Latitude       Epicentre   Time  Magnitude       Date
# 60     85.73    27.96  Sindhupalchowk  21:57        5.3 2015-06-11
# 61     85.78    27.80  Sindhupalchowk  10:02        4.6 2015-06-11
# 62     86.07    27.67         Dolakha  00:26        4.0 2015-06-11
# 63     86.10    27.62         Dolakha  14:51        4.2 2015-06-10
# 64     85.61    27.80  Sindhupalchowk  13:36        4.3 2015-06-10
# 65     85.81    27.87  Sindhupalchowk  02:50        4.1 2015-06-10
# 66     86.13    27.87         Dolakha  22:35        4.1 2015-06-07
# 67     85.64    27.90  Sindhupalchowk  11:02        4.6 2015-06-07
# 68     86.18    27.58         Dolakha  22:45        4.0 2015-06-06
# 69     85.86    28.26           Tibet  02:33        4.2 2015-06-06

# %%
dataDate[dataDate.columns][10:20]
# Out:
#    Longitude Latitude       Epicentre   Time  Magnitude       Date
# 10     85.11    28.14         Dhading   8:24        4.1 2015-06-18
# 11     85.94    28.27           Tibet  08:00        5.1 2015-06-17
# 12     85.58    27.90  Sindhupalchowk  06:26        4.0 2015-06-17
# 13     85.59    27.91  Sindhupalchowk  06:14        5.2 2015-06-17
# 14     85.28    27.68       Kathmandu  05:58        4.4 2015-06-17
# 15     85.72    27.86  Sindhupalchowk  07:41        4.3 2015-12-31
# 16     86.12     27.7         Dolakha  03:52        4.2 2015-12-28
# 17     81.29    29.35          Bajura  04:48        4.1 2015-12-26
# 18     86.08    27.79         Dolakha  08:59        4.1 2015-12-23
# 19     81.69    29.44          Bajura  22:16        5.5 2015-12-18

# %%
data = pd.read_csv('earthquake.csv')

# %%
data.dtypes
# Out:
# Longitude     object
# Latitude      object
# Epicentre     object
# Time          object
# Magnitude    float64
# Date          object
# dtype: object

# %%
data.describe()
# Out:
#         Magnitude
# count  443.000000
# mean     4.397968
# std      0.479838
# min      4.000000
# 25%      4.100000
# 50%      4.200000
# 75%      4.500000
# max      7.600000

# %%
data[['Latitude','Longitude']].describe() #top, freq?, set() for unique
# Out:
#        Latitude Longitude
# count       443       443
# unique      114       188
# top       27.80     86.07
# freq         16         9

# %%
data.T
# Out:
#                   0               1           2           3               4    \
# Longitude       85.39           85.49       86.21       85.17           85.75
# Latitude        27.58           27.94       27.66       27.78           27.85
# Epicentre    Lalitpur  Sindhupalchowk     Dolakha     Nuwakot  Sindhupalchowk
# Time            14:45           23:51       23:49       21:07           14:59
# Magnitude         4.1             4.2         4.1         4.3             4.0
# Date       2015/06/26      2015/06/25  2015/06/25  2015/06/25      2015/06/24
#
#                   5               6           7           8           9    \
# Longitude       86.17           86.00       84.94       82.76       84.92
# Latitude        27.67           27.80       28.17       28.65       28.26
# Epicentre     Dolakha  Sindhupalchowk      Gorkha       Rukum      Gorkha
# Time            13:19           19:26        2:40       12:23       13:50
# Magnitude         4.0             4.3         4.2         5.4         4.0
# Date       2015/06/22      2015/06/21  2015/06/20  2015/06/20  2015/06/19
#
#            ...             433         434         435             436  \
# Longitude  ...           85.96       84.82       85.83           85.56
# Latitude   ...            27.6       28.24       28.25           27.93
# Epicentre  ...  Sindhupalchowk      Gorkha      Rasuwa  Sindhupalchowk
# Time       ...           02:17       02:14       02:08           01:56
# Magnitude  ...             4.8         4.3         4.0             4.4
# Date       ...      2015/04/26  2015/04/26  2015/04/26      2015/04/26
#
#                   437         438             439         440             441  \
# Longitude       84.71       85.35           85.56       85.43           85.55
# Latitude        28.14       28.05           27.93       27.71           27.94
# Epicentre      Gorkha      Rasuwa  Sindhupalchowk   Kathmandu  Sindhupalchowk
# Time            01:52       01:49           01:29       00:43           00:14
# Magnitude         4.2         4.0             4.1         4.6             4.1
# Date       2015/04/26  2015/04/26      2015/04/26  2015/04/26      2015/04/26
#
#                       442
# Longitude           85.98
# Latitude            27.78
# Epicentre  Sindhupalchowk
# Time                23:46
# Magnitude             4.1
# Date           2015/04/25
#
# [6 rows x 443 columns]

# %%
data.sort_values(by='Epicentre')
# Out:
#     Longitude Latitude Epicentre   Time  Magnitude        Date
# 226     83.13    28.48   Baglung  15:21        4.2  2015/07/07
# 35      83.36    28.35   Baglung  08:00        4.0  2015/11/20
# 19      81.69    29.44    Bajura  22:16        5.5  2015/12/18
# 17      81.29    29.35    Bajura  04:48        4.1  2015/12/26
# 227     81.74    29.69    Bajura  09:31        4.6  2015/07/07
# ..        ...      ...       ...    ...        ...         ...
# 417     86.05    27.94     Tibet  13:22        5.0  2015/04/26
# 69      85.86    28.26     Tibet  02:33        4.2  2015/06/06
# 276     85.96    28.04     Tibet  01:50        4.2  2015/05/10
# 11      85.94    28.27     Tibet  08:00        5.1  2015/06/17
# 275     86.67    26.94  Udayapur  02:44        4.0  2015/05/10
#
# [443 rows x 6 columns]

# %%
data['Epicentre'][::15]
# Out:
# 0            Lalitpur
# 15     Sindhupalchowk
# 30            Dolakha
# 45            Dolakha
# 60     Sindhupalchowk
# 75           Darchula
# 90            Dolakha
# 105           Dolakha
# 120           Dolakha
# 135           Dolakha
# 150    Sindhupalchowk
# 165         Kathmandu
# 180            Gorkha
# 195    Sindhupalchowk
# 210             Humla
# 225    Sindhupalchowk
# 240           Dolakha
# 255           Dolakha
# 270    Sindhupalchowk
# 285           Dolakha
# 300             Tibet
# 315            Rasuwa
# 330           Nuwakot
# 345            Rasuwa
# 360           Dolakha
# 375           Dhading
# 390            Gorkha
# 405           Dolakha
# 420            Gorkha
# 435            Rasuwa
# Name: Epicentre, dtype: object

# %%
print(set(data['Epicentre']))
# Out:
# {'Bajura', 'Tibet', 'Taplejung', 'Lamjung', 'Sindhupalchowk', 'Rasuwa', 'Panchthar', 'Lalitpur', 'Ramechhap', 'Kaski', 'Kathmandu', 'Dailekh', 'Baglung', 'Rukum', 'Doti', 'Humla', 'Dhading', 'Nuwakot', 'Kavre', 'Myagdi', 'Darchula', 'Udayapur', 'Lalitput', 'Dolakha', 'Kavrepalanchowk', 'Bhojpur', 'Jajarkot', 'Gorkha'}

# %%
data.head()
# Out:
#   Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0     85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1     85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2     86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3     85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4     85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24

# %%
data[data['Magnitude']>4.2]
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 3       85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 6       86.00    27.80  Sindhupalchowk  19:26        4.3  2015/06/21
# 8       82.76    28.65           Rukum  12:23        5.4  2015/06/20
# 11      85.94    28.27           Tibet  08:00        5.1  2015/06/17
# 13      85.59    27.91  Sindhupalchowk  06:14        5.2  2015/06/17
# ..        ...      ...             ...    ...        ...         ...
# 431      85.8    27.82  Sindhupalchowk  02:52        4.8  2015/04/26
# 433     85.96     27.6  Sindhupalchowk  02:17        4.8  2015/04/26
# 434     84.82    28.24          Gorkha  02:14        4.3  2015/04/26
# 436     85.56    27.93  Sindhupalchowk  01:56        4.4  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
#
# [206 rows x 6 columns]

# %%
data[(data['Epicentre']=='Kathmandu') & (data.Magnitude>4)]
# Out:
#     Longitude Latitude  Epicentre   Time  Magnitude        Date
# 14      85.28    27.68  Kathmandu  05:58        4.4  2015/06/17
# 22      85.39    27.78  Kathmandu   6:10        4.1  2015/11/30
# 152     85.29    27.70  Kathmandu  10:42        4.3  2015/08/11
# 165     85.30    27.68  Kathmandu  02:07        4.2  2015/05/13
# 193     85.32    27.70  Kathmandu  22:14        4.6  2015/07/22
# 312     85.32    27.68  Kathmandu  19:47        4.1  2015/04/25
# 393     85.29    27.67  Kathmandu  21:36        4.5  2015/04/27
# 402     85.20    27.75  Kathmandu  03:37        4.1  2015/04/27
# 440     85.43    27.71  Kathmandu  00:43        4.6  2015/04/26

# %%
scaleKathmandu = data[(data['Epicentre']=='Kathmandu') & (data.Magnitude>4)][['Magnitude','Date']]
scaleKathmandu = scaleKathmandu.sort_values(by='Date').set_index('Date')
#scaleKathmandu.plot.hist()
scaleKathmandu.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
data[data['Epicentre']=='Kathmandu']
# Out:
#     Longitude Latitude  Epicentre   Time  Magnitude        Date
# 14      85.28    27.68  Kathmandu  05:58        4.4  2015/06/17
# 22      85.39    27.78  Kathmandu   6:10        4.1  2015/11/30
# 70      85.22    27.70  Kathmandu  14:16        4.0  2015/06/05
# 125     85.20    27.72  Kathmandu  01:49        4.0  2015/08/13
# 146     85.31    27.64  Kathmandu  05:12        4.0  2015/05/28
# 152     85.29    27.70  Kathmandu  10:42        4.3  2015/08/11
# 165     85.30    27.68  Kathmandu  02:07        4.2  2015/05/13
# 193     85.32    27.70  Kathmandu  22:14        4.6  2015/07/22
# 312     85.32    27.68  Kathmandu  19:47        4.1  2015/04/25
# 367     85.30    27.68  Kathmandu  02:56        4.0  2015/05/01
# 393     85.29    27.67  Kathmandu  21:36        4.5  2015/04/27
# 402     85.20    27.75  Kathmandu  03:37        4.1  2015/04/27
# 407      85.3    27.67  Kathmandu  22:08        4.0  2015/04/26
# 426     85.28    27.67  Kathmandu  06:00        4.0  2015/04/26
# 429     85.25    27.69  Kathmandu  05:25        4.0  2015/04/26
# 440     85.43    27.71  Kathmandu  00:43        4.6  2015/04/26

# %%
data['Epicentre'][5:12]
# Out:
# 5            Dolakha
# 6     Sindhupalchowk
# 7             Gorkha
# 8              Rukum
# 9             Gorkha
# 10           Dhading
# 11             Tibet
# Name: Epicentre, dtype: object

# %%
data.Epicentre[2:7]
# Out:
# 2           Dolakha
# 3           Nuwakot
# 4    Sindhupalchowk
# 5           Dolakha
# 6    Sindhupalchowk
# Name: Epicentre, dtype: object

# %%
data.Epicentre.unique()
# Out:
# array(['Lalitpur', 'Sindhupalchowk', 'Dolakha', 'Nuwakot', 'Gorkha',
#        'Rukum', 'Dhading', 'Tibet', 'Kathmandu', 'Bajura',
#        'Kavrepalanchowk', 'Panchthar', 'Myagdi', 'Baglung', 'Rasuwa',
#        'Darchula', 'Humla', 'Lamjung', 'Taplejung', 'Kavre', 'Ramechhap',
#        'Lalitput', 'Udayapur', 'Kaski', 'Jajarkot', 'Bhojpur', 'Doti',
#        'Dailekh'], dtype=object)

# %%
data[data['Epicentre']=='Kathmandu'][5:12]
# Out:
#     Longitude Latitude  Epicentre   Time  Magnitude        Date
# 152     85.29    27.70  Kathmandu  10:42        4.3  2015/08/11
# 165     85.30    27.68  Kathmandu  02:07        4.2  2015/05/13
# 193     85.32    27.70  Kathmandu  22:14        4.6  2015/07/22
# 312     85.32    27.68  Kathmandu  19:47        4.1  2015/04/25
# 367     85.30    27.68  Kathmandu  02:56        4.0  2015/05/01
# 393     85.29    27.67  Kathmandu  21:36        4.5  2015/04/27
# 402     85.20    27.75  Kathmandu  03:37        4.1  2015/04/27

# %%
data.tail()
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 438     85.35    28.05          Rasuwa  01:49        4.0  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25

# %%
data.head(12)
# Out:
#    Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0      85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1      85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2      86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3      85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4      85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# 5      86.17    27.67         Dolakha  13:19        4.0  2015/06/22
# 6      86.00    27.80  Sindhupalchowk  19:26        4.3  2015/06/21
# 7      84.94    28.17          Gorkha   2:40        4.2  2015/06/20
# 8      82.76    28.65           Rukum  12:23        5.4  2015/06/20
# 9      84.92    28.26          Gorkha  13:50        4.0  2015/06/19
# 10     85.11    28.14         Dhading   8:24        4.1  2015/06/18
# 11     85.94    28.27           Tibet  08:00        5.1  2015/06/17

# %%
data[0::40]  # get rows from DataFrame: data
# Out:
#     Longitude Latitude        Epicentre   Time  Magnitude        Date
# 0       85.39    27.58         Lalitpur  14:45        4.1  2015/06/26
# 40      85.23    28.03           Rasuwa  09:28        4.3  2015/10/31
# 80      86.01    27.75   Sindhupalchowk   5:10        4.3  2015/09/03
# 120     86.14    27.93          Dolakha  04:08        4.8  2015/08/18
# 160     86.07    27.63          Dolakha  17:38        4.1  2015/08/05
# 200     86.24    27.76          Dolakha  16:26        4.4  2015/05/12
# 240     86.17    27.63          Dolakha  13:33        4.8  2015/05/12
# 280     85.68    27.92   Sindhupalchowk  23:27        4.1  2015/06/29
# 320     85.50    27.91   Sindhupalchowk  16:50        4.6  2015/04/25
# 360     86.28    27.74          Dolakha  05:55        4.3  2015/05/02
# 400     85.74    27.57  Kavrepalanchowk  04:17        4.5  2015/04/27
# 440     85.43    27.71        Kathmandu  00:43        4.6  2015/04/26

# %%
#some filtering of Data
data[data['Magnitude']>=4.5 ]
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 8       82.76    28.65           Rukum  12:23        5.4  2015/06/20
# 11      85.94    28.27           Tibet  08:00        5.1  2015/06/17
# 13      85.59    27.91  Sindhupalchowk  06:14        5.2  2015/06/17
# 19      81.69    29.44          Bajura  22:16        5.5  2015/12/18
# 24      87.95    27.11       Panchthar  10:37        4.6  2015/11/27
# ..        ...      ...             ...    ...        ...         ...
# 428     86.07    27.67         Dolakha  05:26        4.5  2015/04/26
# 430     85.02    27.99         Nuwakot  05:01        5.5  2015/04/26
# 431      85.8    27.82  Sindhupalchowk  02:52        4.8  2015/04/26
# 433     85.96     27.6  Sindhupalchowk  02:17        4.8  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
#
# [142 rows x 6 columns]

# %%
data[data.Epicentre.isin(['Sindhupalchowk','Nuwakot','Gorkha']) & (data.Magnitude>5.0)]
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 13      85.59    27.91  Sindhupalchowk  06:14        5.2  2015/06/17
# 37      85.75    27.89  Sindhupalchowk  10:00        5.3  2015/11/19
# 60      85.73    27.96  Sindhupalchowk  21:57        5.3  2015/06/11
# 237     85.83    27.80  Sindhupalchowk  13:58        5.3  2015/05/12
# 238     85.94    27.80  Sindhupalchowk  13:51        5.1  2015/05/12
# 305     85.64    27.92  Sindhupalchowk  22:12        5.3  2015/04/25
# 316     84.71    28.16          Gorkha  18:29        5.5  2015/04/25
# 324      85.6       28  Sindhupalchowk  15:15        5.5  2015/04/25
# 325     85.33    27.91         Nuwakot  14:48        5.3  2015/04/25
# 327     84.95    28.18          Gorkha  14:14        5.2  2015/04/25
# 329     85.84    27.78  Sindhupalchowk  14:02        5.2  2015/04/25
# 347     84.72    28.28          Gorkha  12:30        6.6  2015/04/25
# 349     84.75    28.24          Gorkha  11:56        7.6  2015/04/25
# 357     84.76    28.24          Gorkha  11:20        5.1  2015/05/02
# 406     85.87    27.95  Sindhupalchowk  22:10        5.3  2015/04/26
# 418     85.94    27.75  Sindhupalchowk  13:12        5.3  2015/04/26
# 423     85.16     27.8         Nuwakot  08:55        5.1  2015/04/26
# 430     85.02    27.99         Nuwakot  05:01        5.5  2015/04/26

# %%
data.Epicentre.isin(['Sindhupalchowk','Nuwakot','Gorkha']) & (data.Magnitude>5.0)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# Length: 443, dtype: bool

# %%
data[data.Epicentre.isin(['Sindhupalchowk','Nuwakot','Gorkha']) ]#Dolakha
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 1       85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 3       85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4       85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# 6       86.00    27.80  Sindhupalchowk  19:26        4.3  2015/06/21
# 7       84.94    28.17          Gorkha   2:40        4.2  2015/06/20
# ..        ...      ...             ...    ...        ...         ...
# 436     85.56    27.93  Sindhupalchowk  01:56        4.4  2015/04/26
# 437     84.71    28.14          Gorkha  01:52        4.2  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25
#
# [180 rows x 6 columns]

# %%
data[data.Epicentre.str.contains(r'Dol')][2:7]#Dolakha
# Out:
#    Longitude Latitude Epicentre   Time  Magnitude        Date
# 16     86.12     27.7   Dolakha  03:52        4.2  2015/12/28
# 18     86.08    27.79   Dolakha  08:59        4.1  2015/12/23
# 21     86.19    27.86   Dolakha   7:27        4.0  2015/12/07
# 28     86.16    27.70   Dolakha  21:56        4.1  2015/06/16
# 30     86.26    27.74   Dolakha  15:01        4.1  2015/06/14

# %%
data[data.Date.str.contains(r'/04/')] #April
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 299     85.27     28.1          Rasuwa  23:40        4.0  2015/04/25
# 300     85.91    28.34           Tibet  23:27        5.6  2015/04/25
# 301     85.17    27.78         Nuwakot  23:25        4.0  2015/04/25
# 302     85.53     27.9  Sindhupalchowk  23:24        4.0  2015/04/25
# 303     85.83    27.77  Sindhupalchowk  23:19        4.1  2015/04/25
# ..        ...      ...             ...    ...        ...         ...
# 438     85.35    28.05          Rasuwa  01:49        4.0  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25
#
# [114 rows x 6 columns]

# %%
data[data.Epicentre.str.contains(r'Ka')][2:7]
# Out:
#     Longitude Latitude        Epicentre   Time  Magnitude        Date
# 23      85.53    27.63  Kavrepalanchowk  15:23        4.1  2015/11/27
# 70      85.22    27.70        Kathmandu  14:16        4.0  2015/06/05
# 97      85.70    27.64  Kavrepalanchowk  21:21        4.0  2015/05/13
# 125     85.20    27.72        Kathmandu  01:49        4.0  2015/08/13
# 146     85.31    27.64        Kathmandu  05:12        4.0  2015/05/28

# %%
data[data.Date.between('2015/04/25','2015/04/31') & data.Epicentre.str.contains(r'Sindhu')].count()
# Out:
# Longitude    39
# Latitude     39
# Epicentre    39
# Time         39
# Magnitude    39
# Date         39
# dtype: int64

# %%
data[data.Date.str.contains(r'/04/') & data.Epicentre.str.contains(r'Sindhu')][4:9]
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 308      85.9    27.73  Sindhupalchowk  20:25        5.0  2015/04/25
# 311      85.9    27.73  Sindhupalchowk  19:55        4.7  2015/04/25
# 320     85.50    27.91  Sindhupalchowk  16:50        4.6  2015/04/25
# 321     85.85    27.86  Sindhupalchowk  16:25        4.0  2015/04/25
# 322      85.8    27.87  Sindhupalchowk  16:08        4.1  2015/04/25

# %%
data[data.Date.str.contains(r'/04/') & data.Epicentre.str.contains(r'Ka') & (data['Magnitude']>4)]#.uppercase??
# Out:
#     Longitude Latitude        Epicentre   Time  Magnitude        Date
# 312     85.32    27.68        Kathmandu  19:47        4.1  2015/04/25
# 326     85.63    27.65            Kavre  14:40        5.7  2015/04/25
# 350     83.99    28.40            Kaski  01:57        4.1  2015/04/23
# 393     85.29    27.67        Kathmandu  21:36        4.5  2015/04/27
# 397     85.55    27.67  Kavrepalanchowk  08:18        4.2  2015/04/27
# 400     85.74    27.57  Kavrepalanchowk  04:17        4.5  2015/04/27
# 401     85.73    27.56  Kavrepalanchowk  04:15        4.2  2015/04/27
# 402     85.20    27.75        Kathmandu  03:37        4.1  2015/04/27
# 422     85.63    27.64            Kavre  09:06        5.0  2015/04/26
# 440     85.43    27.71        Kathmandu  00:43        4.6  2015/04/26

# %%
data[data.Date.str.contains(r'/04/') & data.Epicentre.str.contains(r'Ka') & (data['Magnitude']>4) & (data.Date=='2015/04/27')]
# Out:
#     Longitude Latitude        Epicentre   Time  Magnitude        Date
# 393     85.29    27.67        Kathmandu  21:36        4.5  2015/04/27
# 397     85.55    27.67  Kavrepalanchowk  08:18        4.2  2015/04/27
# 400     85.74    27.57  Kavrepalanchowk  04:17        4.5  2015/04/27
# 401     85.73    27.56  Kavrepalanchowk  04:15        4.2  2015/04/27
# 402     85.20    27.75        Kathmandu  03:37        4.1  2015/04/27

# %%
data_1=data[data.Date.str.contains(r'/04/') & data.Epicentre.str.contains(r'Ka') & (data['Magnitude']>4)][data.Date=='2015/04/27']
data_1
# Out:
# C:\Python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     Longitude Latitude        Epicentre   Time  Magnitude        Date
# 393     85.29    27.67        Kathmandu  21:36        4.5  2015/04/27
# 397     85.55    27.67  Kavrepalanchowk  08:18        4.2  2015/04/27
# 400     85.74    27.57  Kavrepalanchowk  04:17        4.5  2015/04/27
# 401     85.73    27.56  Kavrepalanchowk  04:15        4.2  2015/04/27
# 402     85.20    27.75        Kathmandu  03:37        4.1  2015/04/27

# %%
data_1[['Epicentre','Magnitude','Date']]
# Out:
#            Epicentre  Magnitude        Date
# 393        Kathmandu        4.5  2015/04/27
# 397  Kavrepalanchowk        4.2  2015/04/27
# 400  Kavrepalanchowk        4.5  2015/04/27
# 401  Kavrepalanchowk        4.2  2015/04/27
# 402        Kathmandu        4.1  2015/04/27

# %%
data_2=data[data.Date.str.contains(r'/04/') & data.Epicentre.str.contains(r'Si') & (data['Magnitude']>=5)]
data_2
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 305     85.64    27.92  Sindhupalchowk  22:12        5.3  2015/04/25
# 308      85.9    27.73  Sindhupalchowk  20:25        5.0  2015/04/25
# 324      85.6       28  Sindhupalchowk  15:15        5.5  2015/04/25
# 329     85.84    27.78  Sindhupalchowk  14:02        5.2  2015/04/25
# 406     85.87    27.95  Sindhupalchowk  22:10        5.3  2015/04/26
# 413      85.6    27.89  Sindhupalchowk  18:56        5.0  2015/04/26
# 418     85.94    27.75  Sindhupalchowk  13:12        5.3  2015/04/26

# %%
data_3=data_2[(data_2.Magnitude>=4.5) & (data_2.Magnitude<=5.5)][["Epicentre","Magnitude","Date"]]
data_3
# Out:
#           Epicentre  Magnitude        Date
# 305  Sindhupalchowk        5.3  2015/04/25
# 308  Sindhupalchowk        5.0  2015/04/25
# 311  Sindhupalchowk        4.7  2015/04/25
# 320  Sindhupalchowk        4.6  2015/04/25
# 324  Sindhupalchowk        5.5  2015/04/25
# 329  Sindhupalchowk        5.2  2015/04/25
# 374  Sindhupalchowk        4.5  2015/04/29
# 386  Sindhupalchowk        4.9  2015/04/28
# 406  Sindhupalchowk        5.3  2015/04/26
# 410  Sindhupalchowk        4.5  2015/04/26
# 413  Sindhupalchowk        5.0  2015/04/26
# 414  Sindhupalchowk        4.5  2015/04/26
# 415  Sindhupalchowk        4.5  2015/04/26
# 416  Sindhupalchowk        4.8  2015/04/26
# 418  Sindhupalchowk        5.3  2015/04/26
# 421  Sindhupalchowk        4.5  2015/04/26
# 431  Sindhupalchowk        4.8  2015/04/26
# 433  Sindhupalchowk        4.8  2015/04/26

# %%
data_3.columns #to verify defined columns in dataset
# Out:
# Index(['Epicentre', 'Magnitude', 'Date'], dtype='object')

# %%
data_2.columns
# Out:
# Index(['Longitude', 'Latitude', 'Epicentre', 'Time', 'Magnitude', 'Date'], dtype='object')

# %%
newdata=data
newdata
# Out:
#     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0       85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1       85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2       86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3       85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4       85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# ..        ...      ...             ...    ...        ...         ...
# 438     85.35    28.05          Rasuwa  01:49        4.0  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25
#
# [443 rows x 6 columns]

# %%
newdata.describe()
# Out:
#         Magnitude
# count  443.000000
# mean     4.397968
# std      0.479838
# min      4.000000
# 25%      4.100000
# 50%      4.200000
# 75%      4.500000
# max      7.600000

# %%
newdata.columns
# Out:
# Index(['Longitude', 'Latitude', 'Epicentre', 'Time', 'Magnitude', 'Date'], dtype='object')

# %%
newdata[newdata.columns].head()
# Out:
#   Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0     85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1     85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2     86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3     85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4     85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24

# %%
newdata.describe()
# Out:
#         Magnitude
# count  443.000000
# mean     4.397968
# std      0.479838
# min      4.000000
# 25%      4.100000
# 50%      4.200000
# 75%      4.500000
# max      7.600000

# %%
newdata[['Latitude','Longitude','Date','Time','Epicentre']].describe() 
#Top: Highly repeated value(mode of object),
#frequency: frequency of Top
# Out:
#        Latitude Longitude        Date   Time Epicentre
# count       443       443         443    443       443
# unique      114       188         139    390        28
# top       27.80     86.09  2015/04/26  16:44   Dolakha
# freq         16         9          38      4       143

# %%
#Describe for all columns

newdata.describe(include='all')
# Out:
#        Longitude Latitude Epicentre   Time   Magnitude        Date
# count        443      443       443    443  443.000000         443
# unique       188      114        28    390         NaN         139
# top        86.09    27.80   Dolakha  16:44         NaN  2015/04/26
# freq           9       16       143      4         NaN          38
# mean         NaN      NaN       NaN    NaN    4.397968         NaN
# std          NaN      NaN       NaN    NaN    0.479838         NaN
# min          NaN      NaN       NaN    NaN    4.000000         NaN
# 25%          NaN      NaN       NaN    NaN    4.100000         NaN
# 50%          NaN      NaN       NaN    NaN    4.200000         NaN
# 75%          NaN      NaN       NaN    NaN    4.500000         NaN
# max          NaN      NaN       NaN    NaN    7.600000         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Longitude  443 non-null    object
#  1   Latitude   443 non-null    object
#  2   Epicentre  443 non-null    object
#  3   Time       443 non-null    object
#  4   Magnitude  443 non-null    float64
#  5   Date       443 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 20.9+ KB

# %%
data.info
# Out:
# <bound method DataFrame.info of     Longitude Latitude       Epicentre   Time  Magnitude        Date
# 0       85.39    27.58        Lalitpur  14:45        4.1  2015/06/26
# 1       85.49    27.94  Sindhupalchowk  23:51        4.2  2015/06/25
# 2       86.21    27.66         Dolakha  23:49        4.1  2015/06/25
# 3       85.17    27.78         Nuwakot  21:07        4.3  2015/06/25
# 4       85.75    27.85  Sindhupalchowk  14:59        4.0  2015/06/24
# ..        ...      ...             ...    ...        ...         ...
# 438     85.35    28.05          Rasuwa  01:49        4.0  2015/04/26
# 439     85.56    27.93  Sindhupalchowk  01:29        4.1  2015/04/26
# 440     85.43    27.71       Kathmandu  00:43        4.6  2015/04/26
# 441     85.55    27.94  Sindhupalchowk  00:14        4.1  2015/04/26
# 442     85.98    27.78  Sindhupalchowk  23:46        4.1  2015/04/25
#
# [443 rows x 6 columns]>

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Longitude  443 non-null    object
#  1   Latitude   443 non-null    object
#  2   Epicentre  443 non-null    object
#  3   Time       443 non-null    object
#  4   Magnitude  443 non-null    float64
#  5   Date       443 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 20.9+ KB

# %%
data_4=newdata["Magnitude"].astype('str')
data_4
# Out:
# 0      4.1
# 1      4.2
# 2      4.1
# 3      4.3
# 4      4.0
#       ...
# 438    4.0
# 439    4.1
# 440    4.6
# 441    4.1
# 442    4.1
# Name: Magnitude, Length: 443, dtype: object

# %%
data_4.describe(include='all')
# Out:
# count     443
# unique     25
# top       4.0
# freq      100
# Name: Magnitude, dtype: object

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Longitude  443 non-null    object
#  1   Latitude   443 non-null    object
#  2   Epicentre  443 non-null    object
#  3   Time       443 non-null    object
#  4   Magnitude  443 non-null    float64
#  5   Date       443 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 20.9+ KB

# %% [markdown]
# # Task:How to covert all columns of dataframe into object?

# %%
all_columns=newdata[newdata.columns].astype('str')
all_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Longitude  443 non-null    object
#  1   Latitude   443 non-null    object
#  2   Epicentre  443 non-null    object
#  3   Time       443 non-null    object
#  4   Magnitude  443 non-null    object
#  5   Date       443 non-null    object
# dtypes: object(6)
# memory usage: 20.9+ KB

# %%
all_columns.describe()
# Out:
#        Longitude Latitude Epicentre   Time Magnitude        Date
# count        443      443       443    443       443         443
# unique       188      114        28    390        25         139
# top        86.09    27.80   Dolakha  16:44       4.0  2015/04/26
# freq           9       16       143      4       100          38

# %%
newdata.describe(percentiles=[0.15,0.50,.65,0.75],include='all')
# Out:
#        Longitude Latitude Epicentre   Time   Magnitude        Date
# count        443      443       443    443  443.000000         443
# unique       188      114        28    390         NaN         139
# top        86.09    27.80   Dolakha  16:44         NaN  2015/04/26
# freq           9       16       143      4         NaN          38
# mean         NaN      NaN       NaN    NaN    4.397968         NaN
# std          NaN      NaN       NaN    NaN    0.479838         NaN
# min          NaN      NaN       NaN    NaN    4.000000         NaN
# 15%          NaN      NaN       NaN    NaN    4.000000         NaN
# 50%          NaN      NaN       NaN    NaN    4.200000         NaN
# 65%          NaN      NaN       NaN    NaN    4.400000         NaN
# 75%          NaN      NaN       NaN    NaN    4.500000         NaN
# max          NaN      NaN       NaN    NaN    7.600000         NaN

# %% [markdown]
# # 1. Implement  >> Set-Index,Pivot Table, GroupBy, Few Plots

# %% [markdown]
# # 2. How to acquire unique rows from dataset?

# %% [markdown]
# # 3. Create EXCEL using >>  to_excel(filename,sheet_name,index)
# Create a excel file with 3 different 'sheets' each containing certain distinguish data obtained from analysis above!!
